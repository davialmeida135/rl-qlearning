# %% [markdown]
# # Importações

# %%
# !pip install gymnasium
# !pip install pygame
# Out:
# Collecting gymnasium
#   Downloading gymnasium-1.2.1-py3-none-any.whl.metadata (10.0 kB)
# Requirement already satisfied: numpy>=1.21.0 in d:\apps\anaconda3\envs\datascience\lib\site-packages (from gymnasium) (2.1.3)
# Collecting cloudpickle>=1.2.0 (from gymnasium)
#   Using cached cloudpickle-3.1.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: typing-extensions>=4.3.0 in d:\apps\anaconda3\envs\datascience\lib\site-packages (from gymnasium) (4.12.2)
# Collecting farama-notifications>=0.0.1 (from gymnasium)
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl.metadata (558 bytes)
# Downloading gymnasium-1.2.1-py3-none-any.whl (951 kB)
#    ---------------------------------------- 0.0/951.1 kB ? eta -:--:--
#    --------------------------------------- 951.1/951.1 kB 45.9 MB/s eta 0:00:00
# Using cached cloudpickle-3.1.1-py3-none-any.whl (20 kB)
# Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Installing collected packages: farama-notifications, cloudpickle, gymnasium
# Successfully installed cloudpickle-3.1.1 farama-notifications-0.0.4 gymnasium-1.2.1
# Collecting pygame
#   Downloading pygame-2.6.1-cp312-cp312-win_amd64.whl.metadata (13 kB)
# Downloading pygame-2.6.1-cp312-cp312-win_amd64.whl (10.6 MB)
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    ----------- ---------------------------- 3.1/10.6 MB 20.6 MB/s eta 0:00:01
#    --------------------------- ------------ 7.3/10.6 MB 19.7 MB/s eta 0:00:01
#    ---------------------------------------- 10.6/10.6 MB 21.4 MB/s eta 0:00:00
# Installing collected packages: pygame
# Successfully installed pygame-2.6.1

# %%
import gymnasium as gym
import numpy as np
import random
import time

# %% [markdown]
# # Setup Ambiente

# %%
# Ambiente 8x8 e estocástico (escorregadio)
env = gym.make("FrozenLake-v1", is_slippery=True, map_name='8x8')

# %%
# 1. INICIALIZAÇÃO DA Q-TABLE
env.reset()

n_estados = env.observation_space.n
n_acoes = env.action_space.n
q_table = np.zeros((n_estados, n_acoes))
print(f"Q-table inicializada com formato: {q_table.shape}")
print("-" * 30)

# 2. HIPERPARÂMETROS AJUSTADOS PARA AMBIENTE COMPLEXO
total_episodios = 250_000
total_passos_max = 250

taxa_aprendizado = 0.001
fator_desconto = 0.99

epsilon = 1.0
epsilon_min = 0.01
taxa_decaimento = 0.00002
# Out:
# Q-table inicializada com formato: (64, 4)
# ------------------------------

# %% [markdown]
# ## Helper

# %%
from dataclasses import dataclass
@dataclass
class ModeloTreinado:
    q_table: np.ndarray
    n_estados: int
    n_acoes: int
    taxa_aprendizado: float
    fator_desconto: float
    epsilon: float
    epsilon_min: float
    taxa_decaimento: float
    total_episodios: int
    total_passos_max: int
    ambiente: str

# %%
import json
import pickle
import numpy as np
from datetime import datetime
import os

# Função para salvar o modelo de forma mais organizada
def salvar_modelo(modelo, nome_ambiente="FrozenLake-8x8", versao="v1"):
    """
    Salva o modelo treinado com metadados completos e múltiplos formatos
    """
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    
    # Criando estrutura de diretórios
    base_dir = "modelos"
    modelo_dir = f"{base_dir}/{nome_ambiente}/{timestamp}"
    os.makedirs(modelo_dir, exist_ok=True)
    
    # Preparando dados do modelo com metadados
    dados_modelo = {
        "info": {
            "nome_ambiente": nome_ambiente,
            "versao": versao,
            "data_treinamento": datetime.now().isoformat(),
            "timestamp": timestamp,
            "forma_q_table": modelo.q_table.shape,
            "total_estados": modelo.q_table.shape[0],
            "total_acoes": modelo.q_table.shape[1]
        },
        "hiperparametros": {
            "total_episodios": modelo.total_episodios,
            "total_passos_max": modelo.total_passos_max,
            "taxa_aprendizado": modelo.taxa_aprendizado,
            "fator_desconto": modelo.fator_desconto,
            "epsilon_inicial": 1.0,
            "epsilon_final": modelo.epsilon,
            "epsilon_min": modelo.epsilon_min,
            "taxa_decaimento": modelo.taxa_decaimento
        },
        "q_table": modelo.q_table.tolist(),  # Convertendo numpy array para lista
        "estatisticas": {
            "valor_max_q": float(np.max(modelo.q_table)),
            "valor_min_q": float(np.min(modelo.q_table)),
            "valor_medio_q": float(np.mean(modelo.q_table)),
            "estados_visitados": int(np.count_nonzero(np.any(modelo.q_table != 0, axis=1)))
        }
    }
    
    # Nome do arquivo com timestamp
    nome_arquivo = f"qlearning_{timestamp}"
    
    # Salvando em JSON (legível)
    caminho_json = f"{modelo_dir}/{nome_arquivo}.json"
    with open(caminho_json, "w", encoding='utf-8') as f:
        json.dump(dados_modelo, f, indent=2, ensure_ascii=False)
    
    # Salvando em Pickle (mais eficiente para arrays numpy)
    caminho_pickle = f"{modelo_dir}/{nome_arquivo}.pkl"
    with open(caminho_pickle, "wb") as f:
        pickle.dump(dados_modelo, f)
    
    # Salvando Q-table separadamente em formato numpy
    caminho_qtable = f"{modelo_dir}/{nome_arquivo}_qtable.npy"
    np.save(caminho_qtable, modelo.q_table)
    
    # Criando arquivo de resumo legível
    resumo = f"""
MODELO Q-LEARNING TREINADO
==========================
Ambiente: {nome_ambiente}
Data: {datetime.now().strftime("%d/%m/%Y %H:%M:%S")}
Episódios de treinamento: {modelo.total_episodios:,}

HIPERPARÂMETROS:
- Taxa de aprendizado: {modelo.taxa_aprendizado}
- Fator de desconto: {modelo.fator_desconto}
- Epsilon final: {modelo.epsilon:.6f}
- Epsilon mínimo: {modelo.epsilon_min}
- Taxa de decaimento: {modelo.taxa_decaimento}

ESTATÍSTICAS DA Q-TABLE:
- Dimensões: {modelo.q_table.shape}
- Valor máximo: {np.max(modelo.q_table):.4f}
- Valor mínimo: {np.min(modelo.q_table):.4f}
- Valor médio: {np.mean(modelo.q_table):.4f}
- Estados visitados: {np.count_nonzero(np.any(modelo.q_table != 0, axis=1))}/{modelo.q_table.shape[0]}

ARQUIVOS GERADOS:
- {nome_arquivo}.json (dados completos legíveis)
- {nome_arquivo}.pkl (dados completos compactos)
- {nome_arquivo}_qtable.npy (apenas Q-table)
- {nome_arquivo}_resumo.txt (este resumo)
"""
    
    caminho_resumo = f"{modelo_dir}/{nome_arquivo}_resumo.txt"
    with open(caminho_resumo, "w", encoding='utf-8') as f:
        f.write(resumo)
    
    print(f"✅ Modelo salvo com sucesso!")
    print(f"📁 Diretório: {modelo_dir}")
    print(f"🏷️  Nome base: {nome_arquivo}")
    print(f"📊 Arquivos gerados: JSON, PKL, NPY, TXT")
    
    return {
        "diretorio": modelo_dir,
        "nome_base": nome_arquivo,
        "arquivos": {
            "json": caminho_json,
            "pickle": caminho_pickle,
            "qtable": caminho_qtable,
            "resumo": caminho_resumo
        }
    }

# %%
# Função para carregar o modelo
def carregar_modelo(caminho_arquivo):
    """
    Carrega um modelo salvo (aceita arquivos .json ou .pkl)
    """
    if caminho_arquivo.endswith('.json'):
        with open(caminho_arquivo, 'r', encoding='utf-8') as f:
            dados = json.load(f)
        # Convertendo Q-table de volta para numpy array
        dados['q_table'] = np.array(dados['q_table'])
    elif caminho_arquivo.endswith('.pkl'):
        with open(caminho_arquivo, 'rb') as f:
            dados = pickle.load(f)
        dados['q_table'] = np.array(dados['q_table'])
    else:
        raise ValueError("Arquivo deve ser .json ou .pkl")
    
    print(f"✅ Modelo carregado: {dados['info']['nome_ambiente']}")
    print(f"📅 Treinado em: {dados['info']['data_treinamento']}")
    print(f"🎯 Episódios: {dados['hiperparametros']['total_episodios']:,}")
    
    return dados

# %% [markdown]
# # Treino

# %%
# 3. ALGORITMO DE TREINAMENTO Q-LEARNING
print("Iniciando o treinamento para o mapa 8x8 estocástico...")
recompensas_por_episodio = []
taxas_de_sucesso = []

for episodio in range(total_episodios):
    estado, info = env.reset()
    finalizado = False

    # Escolha da ação inicial
    if random.uniform(0, 1) < epsilon:
        acao = env.action_space.sample()
    else:
        acao = np.argmax(q_table[estado, :])

    for passo in range(total_passos_max):

        novo_estado, recompensa, terminado, truncado, info = env.step(acao)
        finalizado = terminado or truncado

        # ==================================================================
        # LÓGICA DE RECOMPENSA APRIMORADA
        # if finalizado and recompensa == 0:
        #     recompensa_modificada = -0.5  # <-- MUDANÇA: Punição maior por cair no buraco
        # elif not finalizado:
        #     recompensa_modificada = -0.01 # Punição pequena por passo
        # else:
        #     recompensa_modificada = recompensa # Recompensa positiva do objetivo
        # ==================================================================

        if finalizado:
            proxima_acao = None
            q_proximo = 0
        else:
            if random.uniform(0, 1) < epsilon:
                proxima_acao = env.action_space.sample()
            else:
                proxima_acao = np.argmax(q_table[novo_estado, :])
            q_proximo = q_table[novo_estado, proxima_acao]

        recompensa_modificada = recompensa  # Mantém a recompensa original

        # SARSA Update: Q(S,A) = Q(S,A) + lr[R + decay*Q(S',A') - Q(S,A)]
        q_table[estado, acao] = q_table[estado, acao] + taxa_aprendizado * \
            (recompensa_modificada + fator_desconto * q_proximo - q_table[estado, acao])

        estado = novo_estado
        acao = proxima_acao

        if finalizado:
            # A recompensa original (0 ou 1) é usada para avaliar o sucesso
            recompensas_por_episodio.append(recompensa)
            break

    # Atualização de Epsilon
    epsilon = max(epsilon_min, np.exp(-taxa_decaimento * episodio))

    # Log de progresso
    if (episodio + 1) % 1000 == 0:
        # Pega os últimos 1000 episódios que terminaram para calcular a taxa de sucesso
        taxa_sucesso = sum(recompensas_por_episodio[-1000:])
        print(f"Episódio: {episodio + 1} | Sucessos (últimos 1k): {taxa_sucesso} | Epsilon: {epsilon:.4f}")
        taxas_de_sucesso.append(taxa_sucesso)

env.close()

print("-" * 30)
print("Treinamento finalizado.\n")
# Out:
# Iniciando o treinamento para o mapa 8x8 estocástico...
# Episódio: 1000 | Sucessos (últimos 1k): 3 | Epsilon: 0.9802
# Episódio: 2000 | Sucessos (últimos 1k): 1 | Epsilon: 0.9608
# Episódio: 3000 | Sucessos (últimos 1k): 1 | Epsilon: 0.9418
# Episódio: 4000 | Sucessos (últimos 1k): 5 | Epsilon: 0.9231
# Episódio: 5000 | Sucessos (últimos 1k): 2 | Epsilon: 0.9049
# Episódio: 6000 | Sucessos (últimos 1k): 3 | Epsilon: 0.8869
# Episódio: 7000 | Sucessos (últimos 1k): 2 | Epsilon: 0.8694
# Episódio: 8000 | Sucessos (últimos 1k): 2 | Epsilon: 0.8522
# Episódio: 9000 | Sucessos (últimos 1k): 3 | Epsilon: 0.8353
# Episódio: 10000 | Sucessos (últimos 1k): 6 | Epsilon: 0.8187
# Episódio: 11000 | Sucessos (últimos 1k): 4 | Epsilon: 0.8025
# Episódio: 12000 | Sucessos (últimos 1k): 4 | Epsilon: 0.7866
# Episódio: 13000 | Sucessos (últimos 1k): 5 | Epsilon: 0.7711
# Episódio: 14000 | Sucessos (últimos 1k): 5 | Epsilon: 0.7558
# Episódio: 15000 | Sucessos (últimos 1k): 5 | Epsilon: 0.7408
# Episódio: 16000 | Sucessos (últimos 1k): 5 | Epsilon: 0.7262
# Episódio: 17000 | Sucessos (últimos 1k): 1 | Epsilon: 0.7118
# Episódio: 18000 | Sucessos (últimos 1k): 3 | Epsilon: 0.6977
# Episódio: 19000 | Sucessos (últimos 1k): 6 | Epsilon: 0.6839
# Episódio: 20000 | Sucessos (últimos 1k): 2 | Epsilon: 0.6703
# Episódio: 21000 | Sucessos (últimos 1k): 6 | Epsilon: 0.6571
# Episódio: 22000 | Sucessos (últimos 1k): 2 | Epsilon: 0.6440
# Episódio: 23000 | Sucessos (últimos 1k): 4 | Epsilon: 0.6313
# Episódio: 24000 | Sucessos (últimos 1k): 6 | Epsilon: 0.6188
# Episódio: 25000 | Sucessos (últimos 1k): 8 | Epsilon: 0.6065
# Episódio: 26000 | Sucessos (últimos 1k): 5 | Epsilon: 0.5945
# Episódio: 27000 | Sucessos (últimos 1k): 3 | Epsilon: 0.5828
# Episódio: 28000 | Sucessos (últimos 1k): 3 | Epsilon: 0.5712
# Episódio: 29000 | Sucessos (últimos 1k): 13 | Epsilon: 0.5599
# Episódio: 30000 | Sucessos (últimos 1k): 9 | Epsilon: 0.5488
# Episódio: 31000 | Sucessos (últimos 1k): 6 | Epsilon: 0.5380
# Episódio: 32000 | Sucessos (últimos 1k): 8 | Epsilon: 0.5273
# Episódio: 33000 | Sucessos (últimos 1k): 11 | Epsilon: 0.5169
# Episódio: 34000 | Sucessos (últimos 1k): 8 | Epsilon: 0.5066
# Episódio: 35000 | Sucessos (últimos 1k): 13 | Epsilon: 0.4966
# Episódio: 36000 | Sucessos (últimos 1k): 6 | Epsilon: 0.4868
# Episódio: 37000 | Sucessos (últimos 1k): 8 | Epsilon: 0.4771
# Episódio: 38000 | Sucessos (últimos 1k): 10 | Epsilon: 0.4677
# Episódio: 39000 | Sucessos (últimos 1k): 14 | Epsilon: 0.4584
# Episódio: 40000 | Sucessos (últimos 1k): 18 | Epsilon: 0.4493
# Episódio: 41000 | Sucessos (últimos 1k): 14 | Epsilon: 0.4404
# Episódio: 42000 | Sucessos (últimos 1k): 6 | Epsilon: 0.4317
# Episódio: 43000 | Sucessos (últimos 1k): 14 | Epsilon: 0.4232
# Episódio: 44000 | Sucessos (últimos 1k): 16 | Epsilon: 0.4148
# Episódio: 45000 | Sucessos (últimos 1k): 5 | Epsilon: 0.4066
# Episódio: 46000 | Sucessos (últimos 1k): 14 | Epsilon: 0.3985
# Episódio: 47000 | Sucessos (últimos 1k): 14 | Epsilon: 0.3906
# Episódio: 48000 | Sucessos (últimos 1k): 8 | Epsilon: 0.3829
# Episódio: 49000 | Sucessos (últimos 1k): 9 | Epsilon: 0.3753
# Episódio: 50000 | Sucessos (últimos 1k): 14 | Epsilon: 0.3679
# Episódio: 51000 | Sucessos (últimos 1k): 10 | Epsilon: 0.3606
# Episódio: 52000 | Sucessos (últimos 1k): 12 | Epsilon: 0.3535
# Episódio: 53000 | Sucessos (últimos 1k): 10 | Epsilon: 0.3465
# Episódio: 54000 | Sucessos (últimos 1k): 16 | Epsilon: 0.3396
# Episódio: 55000 | Sucessos (últimos 1k): 20 | Epsilon: 0.3329
# Episódio: 56000 | Sucessos (últimos 1k): 14 | Epsilon: 0.3263
# Episódio: 57000 | Sucessos (últimos 1k): 10 | Epsilon: 0.3198
# Episódio: 58000 | Sucessos (últimos 1k): 14 | Epsilon: 0.3135
# Episódio: 59000 | Sucessos (últimos 1k): 17 | Epsilon: 0.3073
# Episódio: 60000 | Sucessos (últimos 1k): 12 | Epsilon: 0.3012
# Episódio: 61000 | Sucessos (últimos 1k): 14 | Epsilon: 0.2952
# Episódio: 62000 | Sucessos (últimos 1k): 21 | Epsilon: 0.2894
# Episódio: 63000 | Sucessos (últimos 1k): 19 | Epsilon: 0.2837
# Episódio: 64000 | Sucessos (últimos 1k): 13 | Epsilon: 0.2780
# Episódio: 65000 | Sucessos (últimos 1k): 16 | Epsilon: 0.2725
# Episódio: 66000 | Sucessos (últimos 1k): 17 | Epsilon: 0.2671
# Episódio: 67000 | Sucessos (últimos 1k): 18 | Epsilon: 0.2619
# Episódio: 68000 | Sucessos (últimos 1k): 19 | Epsilon: 0.2567
# Episódio: 69000 | Sucessos (últimos 1k): 16 | Epsilon: 0.2516
# Episódio: 70000 | Sucessos (últimos 1k): 18 | Epsilon: 0.2466
# Episódio: 71000 | Sucessos (últimos 1k): 21 | Epsilon: 0.2417
# Episódio: 72000 | Sucessos (últimos 1k): 11 | Epsilon: 0.2369
# Episódio: 73000 | Sucessos (últimos 1k): 19 | Epsilon: 0.2322
# Episódio: 74000 | Sucessos (últimos 1k): 22 | Epsilon: 0.2276
# Episódio: 75000 | Sucessos (últimos 1k): 24 | Epsilon: 0.2231
# Episódio: 76000 | Sucessos (últimos 1k): 22 | Epsilon: 0.2187
# Episódio: 77000 | Sucessos (últimos 1k): 15 | Epsilon: 0.2144
# Episódio: 78000 | Sucessos (últimos 1k): 20 | Epsilon: 0.2101
# Episódio: 79000 | Sucessos (últimos 1k): 14 | Epsilon: 0.2060
# Episódio: 80000 | Sucessos (últimos 1k): 21 | Epsilon: 0.2019
# Episódio: 81000 | Sucessos (últimos 1k): 13 | Epsilon: 0.1979
# Episódio: 82000 | Sucessos (últimos 1k): 9 | Epsilon: 0.1940
# Episódio: 83000 | Sucessos (últimos 1k): 22 | Epsilon: 0.1901
# Episódio: 84000 | Sucessos (últimos 1k): 14 | Epsilon: 0.1864
# Episódio: 85000 | Sucessos (últimos 1k): 20 | Epsilon: 0.1827
# Episódio: 86000 | Sucessos (últimos 1k): 20 | Epsilon: 0.1791
# Episódio: 87000 | Sucessos (últimos 1k): 18 | Epsilon: 0.1755
# Episódio: 88000 | Sucessos (últimos 1k): 23 | Epsilon: 0.1720
# Episódio: 89000 | Sucessos (últimos 1k): 27 | Epsilon: 0.1686
# Episódio: 90000 | Sucessos (últimos 1k): 22 | Epsilon: 0.1653
# Episódio: 91000 | Sucessos (últimos 1k): 22 | Epsilon: 0.1620
# Episódio: 92000 | Sucessos (últimos 1k): 23 | Epsilon: 0.1588
# Episódio: 93000 | Sucessos (últimos 1k): 17 | Epsilon: 0.1557
# Episódio: 94000 | Sucessos (últimos 1k): 20 | Epsilon: 0.1526
# Episódio: 95000 | Sucessos (últimos 1k): 28 | Epsilon: 0.1496
# Episódio: 96000 | Sucessos (últimos 1k): 19 | Epsilon: 0.1466
# Episódio: 97000 | Sucessos (últimos 1k): 23 | Epsilon: 0.1437
# Episódio: 98000 | Sucessos (últimos 1k): 26 | Epsilon: 0.1409
# Episódio: 99000 | Sucessos (últimos 1k): 20 | Epsilon: 0.1381
# Episódio: 100000 | Sucessos (últimos 1k): 12 | Epsilon: 0.1353
# Episódio: 101000 | Sucessos (últimos 1k): 21 | Epsilon: 0.1327
# Episódio: 102000 | Sucessos (últimos 1k): 13 | Epsilon: 0.1300
# Episódio: 103000 | Sucessos (últimos 1k): 26 | Epsilon: 0.1275
# Episódio: 104000 | Sucessos (últimos 1k): 33 | Epsilon: 0.1249
# Episódio: 105000 | Sucessos (últimos 1k): 17 | Epsilon: 0.1225
# Episódio: 106000 | Sucessos (últimos 1k): 25 | Epsilon: 0.1200
# Episódio: 107000 | Sucessos (últimos 1k): 22 | Epsilon: 0.1177
# Episódio: 108000 | Sucessos (últimos 1k): 15 | Epsilon: 0.1153
# Episódio: 109000 | Sucessos (últimos 1k): 23 | Epsilon: 0.1130
# Episódio: 110000 | Sucessos (últimos 1k): 15 | Epsilon: 0.1108
# Episódio: 111000 | Sucessos (últimos 1k): 19 | Epsilon: 0.1086
# Episódio: 112000 | Sucessos (últimos 1k): 15 | Epsilon: 0.1065
# Episódio: 113000 | Sucessos (últimos 1k): 21 | Epsilon: 0.1044
# Episódio: 114000 | Sucessos (últimos 1k): 22 | Epsilon: 0.1023
# Episódio: 115000 | Sucessos (últimos 1k): 15 | Epsilon: 0.1003
# Episódio: 116000 | Sucessos (últimos 1k): 20 | Epsilon: 0.0983
# Episódio: 117000 | Sucessos (últimos 1k): 25 | Epsilon: 0.0963
# Episódio: 118000 | Sucessos (últimos 1k): 18 | Epsilon: 0.0944
# Episódio: 119000 | Sucessos (últimos 1k): 24 | Epsilon: 0.0926
# Episódio: 120000 | Sucessos (últimos 1k): 18 | Epsilon: 0.0907
# Episódio: 121000 | Sucessos (últimos 1k): 18 | Epsilon: 0.0889
# Episódio: 122000 | Sucessos (últimos 1k): 22 | Epsilon: 0.0872
# Episódio: 123000 | Sucessos (últimos 1k): 23 | Epsilon: 0.0854
# Episódio: 124000 | Sucessos (últimos 1k): 26 | Epsilon: 0.0837
# Episódio: 125000 | Sucessos (últimos 1k): 26 | Epsilon: 0.0821
# Episódio: 126000 | Sucessos (últimos 1k): 27 | Epsilon: 0.0805
# Episódio: 127000 | Sucessos (últimos 1k): 25 | Epsilon: 0.0789
# Episódio: 128000 | Sucessos (últimos 1k): 15 | Epsilon: 0.0773
# Episódio: 129000 | Sucessos (últimos 1k): 17 | Epsilon: 0.0758
# Episódio: 130000 | Sucessos (últimos 1k): 33 | Epsilon: 0.0743
# Episódio: 131000 | Sucessos (últimos 1k): 26 | Epsilon: 0.0728
# Episódio: 132000 | Sucessos (últimos 1k): 22 | Epsilon: 0.0714
# Episódio: 133000 | Sucessos (últimos 1k): 24 | Epsilon: 0.0699
# Episódio: 134000 | Sucessos (últimos 1k): 22 | Epsilon: 0.0686
# Episódio: 135000 | Sucessos (últimos 1k): 28 | Epsilon: 0.0672
# Episódio: 136000 | Sucessos (últimos 1k): 16 | Epsilon: 0.0659
# Episódio: 137000 | Sucessos (últimos 1k): 21 | Epsilon: 0.0646
# Episódio: 138000 | Sucessos (últimos 1k): 26 | Epsilon: 0.0633
# Episódio: 139000 | Sucessos (últimos 1k): 24 | Epsilon: 0.0620
# Episódio: 140000 | Sucessos (últimos 1k): 29 | Epsilon: 0.0608
# Episódio: 141000 | Sucessos (últimos 1k): 26 | Epsilon: 0.0596
# Episódio: 142000 | Sucessos (últimos 1k): 24 | Epsilon: 0.0584
# Episódio: 143000 | Sucessos (últimos 1k): 26 | Epsilon: 0.0573
# Episódio: 144000 | Sucessos (últimos 1k): 24 | Epsilon: 0.0561
# Episódio: 145000 | Sucessos (últimos 1k): 27 | Epsilon: 0.0550
# Episódio: 146000 | Sucessos (últimos 1k): 24 | Epsilon: 0.0539
# Episódio: 147000 | Sucessos (últimos 1k): 21 | Epsilon: 0.0529
# Episódio: 148000 | Sucessos (últimos 1k): 30 | Epsilon: 0.0518
# Episódio: 149000 | Sucessos (últimos 1k): 19 | Epsilon: 0.0508
# Episódio: 150000 | Sucessos (últimos 1k): 20 | Epsilon: 0.0498
# Episódio: 151000 | Sucessos (últimos 1k): 22 | Epsilon: 0.0488
# Episódio: 152000 | Sucessos (últimos 1k): 21 | Epsilon: 0.0478
# Episódio: 153000 | Sucessos (últimos 1k): 22 | Epsilon: 0.0469
# Episódio: 154000 | Sucessos (últimos 1k): 20 | Epsilon: 0.0460
# Episódio: 155000 | Sucessos (últimos 1k): 31 | Epsilon: 0.0451
# Episódio: 156000 | Sucessos (últimos 1k): 24 | Epsilon: 0.0442
# Episódio: 157000 | Sucessos (últimos 1k): 13 | Epsilon: 0.0433
# Episódio: 158000 | Sucessos (últimos 1k): 25 | Epsilon: 0.0424
# Episódio: 159000 | Sucessos (últimos 1k): 27 | Epsilon: 0.0416
# Episódio: 160000 | Sucessos (últimos 1k): 31 | Epsilon: 0.0408
# Episódio: 161000 | Sucessos (últimos 1k): 32 | Epsilon: 0.0400
# Episódio: 162000 | Sucessos (últimos 1k): 19 | Epsilon: 0.0392
# Episódio: 163000 | Sucessos (últimos 1k): 23 | Epsilon: 0.0384
# Episódio: 164000 | Sucessos (últimos 1k): 19 | Epsilon: 0.0376
# Episódio: 165000 | Sucessos (últimos 1k): 25 | Epsilon: 0.0369
# Episódio: 166000 | Sucessos (últimos 1k): 27 | Epsilon: 0.0362
# Episódio: 167000 | Sucessos (últimos 1k): 19 | Epsilon: 0.0354
# Episódio: 168000 | Sucessos (últimos 1k): 27 | Epsilon: 0.0347
# Episódio: 169000 | Sucessos (últimos 1k): 16 | Epsilon: 0.0340
# Episódio: 170000 | Sucessos (últimos 1k): 23 | Epsilon: 0.0334
# Episódio: 171000 | Sucessos (últimos 1k): 19 | Epsilon: 0.0327
# Episódio: 172000 | Sucessos (últimos 1k): 29 | Epsilon: 0.0321
# Episódio: 173000 | Sucessos (últimos 1k): 26 | Epsilon: 0.0314
# Episódio: 174000 | Sucessos (últimos 1k): 24 | Epsilon: 0.0308
# Episódio: 175000 | Sucessos (últimos 1k): 36 | Epsilon: 0.0302
# Episódio: 176000 | Sucessos (últimos 1k): 25 | Epsilon: 0.0296
# Episódio: 177000 | Sucessos (últimos 1k): 34 | Epsilon: 0.0290
# Episódio: 178000 | Sucessos (últimos 1k): 27 | Epsilon: 0.0284
# Episódio: 179000 | Sucessos (últimos 1k): 20 | Epsilon: 0.0279
# Episódio: 180000 | Sucessos (últimos 1k): 16 | Epsilon: 0.0273
# Episódio: 181000 | Sucessos (últimos 1k): 20 | Epsilon: 0.0268
# Episódio: 182000 | Sucessos (últimos 1k): 34 | Epsilon: 0.0263
# Episódio: 183000 | Sucessos (últimos 1k): 26 | Epsilon: 0.0257
# Episódio: 184000 | Sucessos (últimos 1k): 33 | Epsilon: 0.0252
# Episódio: 185000 | Sucessos (últimos 1k): 27 | Epsilon: 0.0247
# Episódio: 186000 | Sucessos (últimos 1k): 19 | Epsilon: 0.0242
# Episódio: 187000 | Sucessos (últimos 1k): 29 | Epsilon: 0.0238
# Episódio: 188000 | Sucessos (últimos 1k): 27 | Epsilon: 0.0233
# Episódio: 189000 | Sucessos (últimos 1k): 29 | Epsilon: 0.0228
# Episódio: 190000 | Sucessos (últimos 1k): 34 | Epsilon: 0.0224
# Episódio: 191000 | Sucessos (últimos 1k): 28 | Epsilon: 0.0219
# Episódio: 192000 | Sucessos (últimos 1k): 20 | Epsilon: 0.0215
# Episódio: 193000 | Sucessos (últimos 1k): 24 | Epsilon: 0.0211
# Episódio: 194000 | Sucessos (últimos 1k): 28 | Epsilon: 0.0207
# Episódio: 195000 | Sucessos (últimos 1k): 15 | Epsilon: 0.0202
# Episódio: 196000 | Sucessos (últimos 1k): 28 | Epsilon: 0.0198
# Episódio: 197000 | Sucessos (últimos 1k): 22 | Epsilon: 0.0194
# Episódio: 198000 | Sucessos (últimos 1k): 19 | Epsilon: 0.0191
# Episódio: 199000 | Sucessos (últimos 1k): 24 | Epsilon: 0.0187
# Episódio: 200000 | Sucessos (últimos 1k): 24 | Epsilon: 0.0183
# Episódio: 201000 | Sucessos (últimos 1k): 24 | Epsilon: 0.0180
# Episódio: 202000 | Sucessos (últimos 1k): 22 | Epsilon: 0.0176
# Episódio: 203000 | Sucessos (últimos 1k): 27 | Epsilon: 0.0172
# Episódio: 204000 | Sucessos (últimos 1k): 26 | Epsilon: 0.0169
# Episódio: 205000 | Sucessos (últimos 1k): 36 | Epsilon: 0.0166
# Episódio: 206000 | Sucessos (últimos 1k): 30 | Epsilon: 0.0162
# Episódio: 207000 | Sucessos (últimos 1k): 23 | Epsilon: 0.0159
# Episódio: 208000 | Sucessos (últimos 1k): 21 | Epsilon: 0.0156
# Episódio: 209000 | Sucessos (últimos 1k): 31 | Epsilon: 0.0153
# Episódio: 210000 | Sucessos (últimos 1k): 26 | Epsilon: 0.0150
# Episódio: 211000 | Sucessos (últimos 1k): 28 | Epsilon: 0.0147
# Episódio: 212000 | Sucessos (últimos 1k): 30 | Epsilon: 0.0144
# Episódio: 213000 | Sucessos (últimos 1k): 24 | Epsilon: 0.0141
# Episódio: 214000 | Sucessos (últimos 1k): 40 | Epsilon: 0.0138
# Episódio: 215000 | Sucessos (últimos 1k): 28 | Epsilon: 0.0136
# Episódio: 216000 | Sucessos (últimos 1k): 31 | Epsilon: 0.0133
# Episódio: 217000 | Sucessos (últimos 1k): 30 | Epsilon: 0.0130
# Episódio: 218000 | Sucessos (últimos 1k): 28 | Epsilon: 0.0128
# Episódio: 219000 | Sucessos (últimos 1k): 21 | Epsilon: 0.0125
# Episódio: 220000 | Sucessos (últimos 1k): 24 | Epsilon: 0.0123
# Episódio: 221000 | Sucessos (últimos 1k): 24 | Epsilon: 0.0120
# Episódio: 222000 | Sucessos (últimos 1k): 22 | Epsilon: 0.0118
# Episódio: 223000 | Sucessos (últimos 1k): 21 | Epsilon: 0.0116
# Episódio: 224000 | Sucessos (últimos 1k): 25 | Epsilon: 0.0113
# Episódio: 225000 | Sucessos (últimos 1k): 16 | Epsilon: 0.0111
# Episódio: 226000 | Sucessos (últimos 1k): 23 | Epsilon: 0.0109
# Episódio: 227000 | Sucessos (últimos 1k): 30 | Epsilon: 0.0107
# Episódio: 228000 | Sucessos (últimos 1k): 20 | Epsilon: 0.0105
# Episódio: 229000 | Sucessos (últimos 1k): 33 | Epsilon: 0.0103
# Episódio: 230000 | Sucessos (últimos 1k): 22 | Epsilon: 0.0101
# Episódio: 231000 | Sucessos (últimos 1k): 27 | Epsilon: 0.0100
# Episódio: 232000 | Sucessos (últimos 1k): 23 | Epsilon: 0.0100
# Episódio: 233000 | Sucessos (últimos 1k): 22 | Epsilon: 0.0100
# Episódio: 234000 | Sucessos (últimos 1k): 33 | Epsilon: 0.0100
# Episódio: 235000 | Sucessos (últimos 1k): 27 | Epsilon: 0.0100
# Episódio: 236000 | Sucessos (últimos 1k): 33 | Epsilon: 0.0100
# Episódio: 237000 | Sucessos (últimos 1k): 24 | Epsilon: 0.0100
# Episódio: 238000 | Sucessos (últimos 1k): 27 | Epsilon: 0.0100
# Episódio: 239000 | Sucessos (últimos 1k): 29 | Epsilon: 0.0100
# Episódio: 240000 | Sucessos (últimos 1k): 19 | Epsilon: 0.0100
# Episódio: 241000 | Sucessos (últimos 1k): 32 | Epsilon: 0.0100
# Episódio: 242000 | Sucessos (últimos 1k): 24 | Epsilon: 0.0100
# Episódio: 243000 | Sucessos (últimos 1k): 27 | Epsilon: 0.0100
# Episódio: 244000 | Sucessos (últimos 1k): 27 | Epsilon: 0.0100
# Episódio: 245000 | Sucessos (últimos 1k): 17 | Epsilon: 0.0100
# Episódio: 246000 | Sucessos (últimos 1k): 37 | Epsilon: 0.0100
# Episódio: 247000 | Sucessos (últimos 1k): 29 | Epsilon: 0.0100
# Episódio: 248000 | Sucessos (últimos 1k): 25 | Epsilon: 0.0100
# Episódio: 249000 | Sucessos (últimos 1k): 28 | Epsilon: 0.0100
# Episódio: 250000 | Sucessos (últimos 1k): 17 | Epsilon: 0.0100
# ------------------------------
# Treinamento finalizado.

# %%
# Gráfico de taxa de sucesso
import matplotlib.pyplot as plt
plt.plot(np.array(taxas_de_sucesso)/1000)
plt.xlabel('Milhares de Episódios')
plt.ylabel('Taxa de Sucesso')
plt.title('Taxa de Sucesso ao Longo do Treinamento')
plt.grid()
plt.show()

# %%
modelo_treinado = ModeloTreinado(
    q_table=q_table,
    n_estados=n_estados,
    n_acoes=n_acoes,
    taxa_aprendizado=taxa_aprendizado,
    fator_desconto=fator_desconto,
    epsilon=epsilon,
    epsilon_min=epsilon_min,
    taxa_decaimento=taxa_decaimento,
    total_episodios=total_episodios,
    total_passos_max=total_passos_max,
    ambiente=env.spec.id
)

# Salvando o modelo com a nova função
info_salvamento = salvar_modelo(modelo_treinado, "FrozenLake-8x8", "v1")
# Out:
# ✅ Modelo salvo com sucesso!
# 📁 Diretório: modelos/FrozenLake-8x8/20251001_185930
# 🏷️  Nome base: qlearning_20251001_185930
# 📊 Arquivos gerados: JSON, PKL, NPY, TXT

# %% [markdown]
# # Avaliação

# %%
modelo_treinado = carregar_modelo(info_salvamento['arquivos']['json'])
# Out:
# ✅ Modelo carregado: FrozenLake-8x8
# 📅 Treinado em: 2025-10-01T18:59:30.119516
# 🎯 Episódios: 250,000

# %%
# 4. AVALIAÇÃO DO AGENTE TREINADO (Versão Segura)
print("\nIniciando avaliação do agente treinado...\n")

# Start with non-visual evaluation first
env_eval = gym.make("FrozenLake-v1", is_slippery=True, map_name='8x8')
sucessos = 0
total_avaliacoes = 500  # More episodes for better statistics

# Use the Q-table from the loaded model
q_table_carregada = modelo_treinado['q_table']
total_passos_max = modelo_treinado['hiperparametros']['total_passos_max']

print("=== AVALIAÇÃO SEM VISUALIZAÇÃO ===")
for episodio in range(total_avaliacoes):
    estado, info = env_eval.reset()
    finalizado = False

    for passo in range(total_passos_max):
        acao = np.argmax(q_table_carregada[estado, :])
        novo_estado, recompensa, terminado, truncado, info = env_eval.step(acao)
        finalizado = terminado or truncado

        if finalizado:
            if recompensa == 1.0:
                sucessos += 1
            break
        estado = novo_estado

    # Progress indicator
    if (episodio + 1) % 10 == 0:
        taxa_atual = (sucessos / (episodio + 1)) * 100
        print(f"Episódios: {episodio + 1}/{total_avaliacoes} | Taxa de sucesso: {taxa_atual:.1f}%")

env_eval.close()
print(f"\n📊 RESULTADO FINAL: Taxa de sucesso: {sucessos/total_avaliacoes*100:.1f}% ({sucessos}/{total_avaliacoes})")
# Out:
# Iniciando avaliação do agente treinado...
#
# === AVALIAÇÃO SEM VISUALIZAÇÃO ===
# Episódios: 10/500 | Taxa de sucesso: 0.0%
# Episódios: 20/500 | Taxa de sucesso: 0.0%
# Episódios: 30/500 | Taxa de sucesso: 0.0%
# Episódios: 40/500 | Taxa de sucesso: 0.0%
# Episódios: 50/500 | Taxa de sucesso: 0.0%
# Episódios: 60/500 | Taxa de sucesso: 0.0%
# Episódios: 70/500 | Taxa de sucesso: 0.0%
# Episódios: 80/500 | Taxa de sucesso: 1.2%
# Episódios: 90/500 | Taxa de sucesso: 2.2%
# Episódios: 100/500 | Taxa de sucesso: 3.0%
# Episódios: 110/500 | Taxa de sucesso: 2.7%
# Episódios: 120/500 | Taxa de sucesso: 2.5%
# Episódios: 130/500 | Taxa de sucesso: 2.3%
# Episódios: 140/500 | Taxa de sucesso: 2.1%
# Episódios: 150/500 | Taxa de sucesso: 2.7%
# Episódios: 160/500 | Taxa de sucesso: 2.5%
# Episódios: 170/500 | Taxa de sucesso: 2.4%
# Episódios: 180/500 | Taxa de sucesso: 2.2%
# Episódios: 190/500 | Taxa de sucesso: 2.1%
# Episódios: 200/500 | Taxa de sucesso: 2.0%
# Episódios: 210/500 | Taxa de sucesso: 1.9%
# Episódios: 220/500 | Taxa de sucesso: 2.3%
# Episódios: 230/500 | Taxa de sucesso: 2.2%
# Episódios: 240/500 | Taxa de sucesso: 2.1%
# Episódios: 250/500 | Taxa de sucesso: 2.0%
# Episódios: 260/500 | Taxa de sucesso: 1.9%
# Episódios: 270/500 | Taxa de sucesso: 2.2%
# Episódios: 280/500 | Taxa de sucesso: 2.1%
# Episódios: 290/500 | Taxa de sucesso: 2.4%
# Episódios: 300/500 | Taxa de sucesso: 2.3%
# Episódios: 310/500 | Taxa de sucesso: 2.6%
# Episódios: 320/500 | Taxa de sucesso: 2.8%
# Episódios: 330/500 | Taxa de sucesso: 2.7%
# Episódios: 340/500 | Taxa de sucesso: 2.6%
# Episódios: 350/500 | Taxa de sucesso: 2.6%
# Episódios: 360/500 | Taxa de sucesso: 2.5%
# Episódios: 370/500 | Taxa de sucesso: 2.4%
# Episódios: 380/500 | Taxa de sucesso: 2.6%
# Episódios: 390/500 | Taxa de sucesso: 2.8%
# Episódios: 400/500 | Taxa de sucesso: 2.8%
# Episódios: 410/500 | Taxa de sucesso: 2.7%
# Episódios: 420/500 | Taxa de sucesso: 2.6%
# Episódios: 430/500 | Taxa de sucesso: 2.6%
# Episódios: 440/500 | Taxa de sucesso: 2.5%
# Episódios: 450/500 | Taxa de sucesso: 2.4%
# Episódios: 460/500 | Taxa de sucesso: 2.6%
# Episódios: 470/500 | Taxa de sucesso: 2.8%
# Episódios: 480/500 | Taxa de sucesso: 2.7%
# Episódios: 490/500 | Taxa de sucesso: 2.9%
# Episódios: 500/500 | Taxa de sucesso: 3.0%
#
# 📊 RESULTADO FINAL: Taxa de sucesso: 3.0% (15/500)
